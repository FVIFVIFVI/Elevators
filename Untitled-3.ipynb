# %%
import tkinter as tk
from PIL import Image, ImageTk
import pygame
import random

sound1 = 'ding.mp3'
imgelv = "elv.png"
imgefloor = "b.png"

class Building:
    num_floors = 8

    def __init__(self, root, floorheight, floor_width, num_of_elv=2, space=1):
        self.root = root
        self.elevators = [Elevator(root, 0, 250 + j * space, floorheight) for j in range(num_of_elv)]
        self.floors = [Floor(root, 0, i * floorheight, floorheight, floor_width, i, self) for i in range(Building.num_floors)]

    def update(self, floor_num, direction):
        # Finding the best elevator based on the requested floor and direction
        selected_elevator = self.elevators[0]
        min_distance = self.elevators[0].myfloor
        for elevator in self.elevators:
            # if  elevator.targets:
            #  b=min(elevator.targets, key=lambda x: x.floor_num).floor_num 
            # else:
            #     b=0
            # a=abs(elevator.myfloor - b) * 0.5 + b
            if elevator.is_moving_in_direction(floor_num, direction) :
                distance = abs(elevator.myfloor - floor_num)
                print(distance,min_distance)
                if distance < min_distance:
                    min_distance = distance
                    selected_elevator = elevator
                
        print(1)
        if selected_elevator:
            selected_elevator.add_target(floor_num)
            print(2)
            if selected_elevator.direction is None:
                selected_elevator.move()

class Elevator:
    def __init__(self, root, initial_pos, initial_posx, floorheight, step=10):
        self.root = root
        self.y_pos = 60
        self.x_pos = initial_posx
        self.floorheight = floorheight
        self.step = step
        self.myfloor = self.y_pos // self.floorheight
        self.direction = None
        self.targets = []
        self.passengers=[]
        pygame.mixer.init()
        self.ding_sound = pygame.mixer.Sound(sound1)
        original_image = Image.open(imgelv)
        resized_image = original_image.resize((100, floorheight), Image.Resampling.LANCZOS)
        self.image = ImageTk.PhotoImage(resized_image)
        self.label = tk.Label(root, image=self.image)
        self.label.image = self.image
        self.label.place(x=self.x_pos, y=self.y_pos)

    def add_target(self, floor):
       
       target =  floor
       if (not self.targets) :
        if self.myfloor < floor.floor_num:
            self.direction = 1
        elif self.myfloor > floor.floor_num:
            self.direction = -1
       if target.destination not in self.targets:
            self.targets.append(target)
            self.targets.sort(key=lambda x: floor.floor_num, reverse=self.direction == -1)##לפי כיוון 
    
    def move(self):
        if not self.targets:
            return
        target_floor = self.targets[0]
        self.direction = 1 if self.myfloor < target_floor else -1  # Ensure direction is set לא צריך

        self.myfloor += self.direction
        self.label.place(y=self.myfloor * self.floorheight)
        for i in self.targets:
         if i.myfloor == target_floor:
            self.ding_sound.play()
            
            i.load1(self,i)
            self.targets.pop(i)###להוסיף משתנה בשביל ספירה
            if not self.targets:
                self.direction = None 
        self.root.after(100, self.move)  

    def is_moving_in_direction(self, floor_num, direction):
        if self.direction is None:
            return True
        if (self.direction == 1 and self.myfloor <= floor_num) or (self.direction == -1 and self.myfloor >= floor_num):
            return True
        return False
   

    def is_moving_in_direction(self, floor_num, direction):
        if self.direction is None:
            return True
        if self.direction == 1 and self.myfloor <= floor_num:
            return direction == 1
        if self.direction == -1 and self.myfloor >= floor_num:
            return direction == -1
        return False

class Floor:
    def __init__(self, root, pos_x, pos_y, height, width, floor_num, building):
        self.root = root
        self.floor_num = floor_num
        self.building = building
        self.passengers=[]
        brick_image = Image.open(imgefloor)
        brick_resized_image = brick_image.resize((width, height), Image.Resampling.LANCZOS)
        self.brick_texture = ImageTk.PhotoImage(brick_resized_image)
        self.label = tk.Label(root, image=self.brick_texture)
        self.label.image = self.brick_texture
        self.label.place(x=pos_x, y=pos_y, width=width, height=height)
        self.number_label = tk.Label(self.label, text=str(floor_num), bg='gray', fg='black')
        self.number_label.pack(side='bottom', fill='x')
        self.call_button = tk.Button(self.label, text="Call Elevator", command=self.add_passenger_and_call_elevator)
        self.call_button.pack(side='top')
    def add_passenger_and_call_elevator(self):
        new_passenger = Passenger(self.floor_num)
        self.passengers.append(new_passenger)  
        direction = 1 if new_passenger.destination > self.floor_num else -1
        self.building.update(self.floor_num, direction)
    def call_elevator(self):
        for i in self.passengers:##לתקן שיעבוד במקביל
         if i.destination>self.floor_num:
             self.building.update(self.floor_num,1)
         else:
             self.building.update(self.floor_num,-1)
        
    def load1(self,elv):
        for j in self.passengers:
                if j.destination<self.floor_num and elv.direction==-1:
                    elv.passengers.append(j)
                    self.passengers.pop(j)##אפשר לשלב 
                if j.destination>self.floor_num and elv.direction==1:
                    elv.passengers.append(j)
                    self.passengers.pop(j)

class Passenger:
    def __init__(self, current_floor):
        self.current_floor = current_floor
        self.destination = random.randint(0, Building.num_floors - 1)


def main():
    root = tk.Tk()
    window_title = "Building Elevator Simulation"
    window_size = "800x600"
    floorheight = 80
    floorwidth = 200
    num_elevators = 2
    elevatorspace = 200

    root.title(window_title)
    root.geometry(window_size)

    building = Building(root, floorheight, floorwidth, num_elevators, elevatorspace)

    root.mainloop()

if __name__ == "__main__":
    main()
# Out:
# 3 0
# 3 0
# 1
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\tkinter\__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\gdkub\AppData\Local\Temp\ipykernel_16020\960292329.py", line 127, in add_passenger_and_call_elevator
#     self.building.update(self.floor_num, direction)
#   File "C:\Users\gdkub\AppData\Local\Temp\ipykernel_16020\960292329.py", line 37, in update
#     selected_elevator.add_target(floor_num)
#   File "C:\Users\gdkub\AppData\Local\Temp\ipykernel_16020\960292329.py", line 64, in add_target
#     self.targets.sort(key=lambda x: x.floor_num, reverse=self.direction == -1)
#   File "C:\Users\gdkub\AppData\Local\Temp\ipykernel_16020\960292329.py", line 64, in <lambda>
#     self.targets.sort(key=lambda x: x.floor_num, reverse=self.direction == -1)
#                                     ^^^^^^^^^^^
# AttributeError: 'int' object has no attribute 'floor_num'
